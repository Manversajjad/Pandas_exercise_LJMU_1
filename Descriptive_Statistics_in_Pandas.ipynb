# %% [markdown]
# <a href="https://colab.research.google.com/github/Manversajjad/Pandas_exercise_LJMU_1/blob/main/Descriptive_Statistics_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
ser1= pd.Series(np.random.randn(80))
ser1
# Out:
# 0    -1.026725
# 1     1.821219
# 2     0.137559
# 3     0.514279
# 4    -0.368174
#         ...
# 75    0.627011
# 76   -1.034142
# 77    0.852289
# 78    1.254676
# 79   -0.422692
# Length: 80, dtype: float64

# %%
# Descriptive Statistics for a series
ser1.describe()
# Out:
# count    80.000000
# mean      0.100019
# std       1.010430
# min      -2.176040
# 25%      -0.669705
# 50%       0.194348
# 75%       0.766268
# max       2.642735
# dtype: float64

# %%
# If wanted to extract particular element from the above, count,mean, std etc. The syntax can be used as follows
ser1.describe()['mean']
# Out:
# 0.10001947223446836

# %% [markdown]
# Generating Descriptive Statistics for a DataFrame

# %%
df1 = pd.DataFrame(np.random.rand(3,3), columns=['A', 'B', 'C'], index=[1, 2, 3])
df1
# Out:
#           A         B         C
# 1  0.641684  0.532770  0.678912
# 2  0.496889  0.203585  0.197129
# 3  0.068697  0.800505  0.175910

# %%
df1.describe()
# Out:
#               A         B         C
# count  3.000000  3.000000  3.000000
# mean   0.402424  0.512287  0.350650
# std    0.297945  0.298986  0.284481
# min    0.068697  0.203585  0.175910
# 25%    0.282793  0.368178  0.186519
# 50%    0.496889  0.532770  0.197129
# 75%    0.569287  0.666638  0.438021
# max    0.641684  0.800505  0.678912

# %%
# For Dataframe we can use LOC function to iterate
df1.describe().loc['mean']
# Out:
# A    0.402424
# B    0.512287
# C    0.350650
# Name: mean, dtype: float64

# %% [markdown]
# Compute Summary Statistics

# %%
df2 = pd.DataFrame(np.random.rand(3,3), columns=['A','B', 'C'], index=[1, 2, 3])
df2
# Out:
#           A         B         C
# 1  0.160027  0.343160  0.424811
# 2  0.499214  0.222974  0.898399
# 3  0.254314  0.083099  0.926070

# %%
# Generate Sum of values for columns
genr = df2.sum(axis=0)
genr
# Out:
# A    0.913556
# B    0.649233
# C    2.249280
# dtype: float64

# %%
# Generate Sum of values for Rows
genr1 = df2.sum(axis=0)
genr1
# Out:
# A    0.913556
# B    0.649233
# C    2.249280
# dtype: float64

# %% [markdown]
# **Practice Problem :- Descriptive Statistics**

# %%
product_sales = pd.DataFrame({'Monday': [32, 152, 94, 0], 'Tuesday': [45, 109, 114, 0], \
                             'Wednesday': [15, 77, 85, 0], 'Thursday': [29, 85, 132, 0], \
                             'Friday': [63, 143, 101, 15], 'Saturday': [87, 211, 186, 25]}, \
                             index=['Cupcakes', 'Pie Slices', 'Brownies', 'Cookies'])
product_sales
# Out:
#             Monday  Tuesday  Wednesday  Thursday  Friday  Saturday
# Cupcakes        32       45         15        29      63        87
# Pie Slices     152      109         77        85     143       211
# Brownies        94      114         85       132     101       186
# Cookies          0        0          0         0      15        25

# %%
# Generate descriptive statistics for the entire DataFrame.
descriptive_statistics1 = product_sales.describe()
descriptive_statistics1
# Out:
#           Monday     Tuesday  Wednesday    Thursday      Friday    Saturday
# count    4.00000    4.000000   4.000000    4.000000    4.000000    4.000000
# mean    69.50000   67.000000  44.250000   61.500000   80.500000  127.250000
# std     67.43639   54.607692  42.999031   58.767905   54.537449   86.680928
# min      0.00000    0.000000   0.000000    0.000000   15.000000   25.000000
# 25%     24.00000   33.750000  11.250000   21.750000   51.000000   71.500000
# 50%     63.00000   77.000000  46.000000   57.000000   82.000000  136.500000
# 75%    108.50000  110.250000  79.000000   96.750000  111.500000  192.250000
# max    152.00000  114.000000  85.000000  132.000000  143.000000  211.000000

# %%
# What is the total number of products sold on each day?
product_sales.sum()
# Out:
# Monday       278
# Tuesday      268
# Wednesday    177
# Thursday     246
# Friday       322
# Saturday     509
# dtype: int64

# %%
# Total number of products sold during the week.
product_sales.sum(axis=1)
# Out:
# Cupcakes      271
# Pie Slices    777
# Brownies      712
# Cookies        40
# dtype: int64

# %%
# For the product type that sold the most across the week, how many were sold?
product_sales.sum(axis=1).max()
# Out:
# 777

# %%
# For the product type that sold the most across the week, list the name of the product and the number sold.
product_sales.sum(axis=1)[product_sales.sum(axis=1).max() == product_sales.sum(axis=1) ]
# Out:
# Pie Slices    777
# dtype: int64
