# %% [markdown]
# <a href="https://colab.research.google.com/github/Manversajjad/Pandas_exercise_LJMU_1/blob/main/Pandas_practice_problem_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
product_sales = pd.DataFrame({'Monday': [32, 152, 94], 'Tuesday': [45, 109, 114], \
                             'Wednesday': [15, 77, 85], 'Thursday': [29, 85, 132], \
                             'Friday': [63, 143, 101]}, \
                             index=['Cupcakes', 'Pie Slices', 'Brownies'])

# %%
# For each day of the week, provide a DataFrame for how many cupcakes, pie slices, and brownies were sold.
product_sales
# Out:
#             Monday  Tuesday  Wednesday  Thursday  Friday
# Cupcakes        32       45         15        29      63
# Pie Slices     152      109         77        85     143
# Brownies        94      114         85       132     101

# %%
# For each day of the week, provide a DataFrame for how many cupcakes and brownies were sold.
total_sales = product_sales.loc[['Cupcakes', 'Brownies']]
total_sales
# Out:
#           Monday  Tuesday  Wednesday  Thursday  Friday
# Cupcakes      32       45         15        29      63
# Brownies      94      114         85       132     101

# %%
# For Thursday and Friday, provide a DataFrame for how many cupcakes, pie slices, and brownies were sold.
Only_Thurs_frid = product_sales[['Thursday', 'Friday']]
Only_Thurs_frid
# Out:
#             Thursday  Friday
# Cupcakes          29      63
# Pie Slices        85     143
# Brownies         132     101

# %%
pie = product_sales.loc['Pie Slices', 'Wednesday']
pie
# Out:
# 77

# %%
product_sales = pd.DataFrame({'Monday': [32, 152, 94], 'Tuesday': [45, 109, 114], \
                             'Wednesday': [15, 77, 85], 'Thursday': [29, 85, 132], \
                             'Friday': [63, 143, 101]}, \
                             index=['Cupcakes', 'Pie Slices', 'Brownies'])

# %%
product_sales
# Out:
#             Monday  Tuesday  Wednesday  Thursday  Friday
# Cupcakes        32       45         15        29      63
# Pie Slices     152      109         77        85     143
# Brownies        94      114         85       132     101

# %%
# A data entry error was made for Thursday's quantity of pie slices. Modify the value to 95.
prod = product_sales.loc['Pie Slices', 'Thursday'] = 95
prod
# Out:
# 95

# %%
# The store wants to do some analysis on its Saturday sales as well. On Saturday, 87 cupcakes, 211 pie slices, and 186 brownies were sold. Modify the DataFrame to include these data points.
product_sales.loc[:, 'Saturday'] = [87, 211, 186]
product_sales
# Out:
#             Monday  Tuesday  Wednesday  Thursday  Friday  Saturday
# Cupcakes        32       45         15        29      63        87
# Pie Slices     152      109         77        95     143       211
# Brownies        94      114         85       132     101       186

# %%
# The store decides to temporarily discard Thursday's sales from its data analysis. Remove this data column without permanently removing it.
product_sales.drop('Thursday', axis=1)
# Out:
#             Monday  Tuesday  Wednesday  Friday  Saturday
# Cupcakes        32       45         15      63        87
# Pie Slices     152      109         77     143       211
# Brownies        94      114         85     101       186

# %%
product_sales
# Out:
#             Monday  Tuesday  Wednesday  Thursday  Friday  Saturday
# Cupcakes        32       45         15        29      63        87
# Pie Slices     152      109         77        95     143       211
# Brownies        94      114         85       132     101       186

# %%
# Challenge: The store just added Cookies to its product line-up selling 15 on Friday and 25 on Saturday.
# Modify the DataFrame to include these data points without using any type of append function. Use logic instead.
product_sales.loc['Cookies'] = pd.Series([15,25], index=['Friday', 'Saturday'])
product_sales
# Out:
#             Monday  Tuesday  Wednesday  Thursday  Friday  Saturday
# Cupcakes      32.0     45.0       15.0      29.0    63.0      87.0
# Pie Slices   152.0    109.0       77.0      95.0   143.0     211.0
# Brownies      94.0    114.0       85.0     132.0   101.0     186.0
# Cookies        NaN      NaN        NaN       NaN    15.0      25.0
